# %%
import numpy as np

# %%
with open('Tnodes.txt') as f:
    a=np.genfromtxt('Tnodes.txt', 
                dtype=None, 
                #comments='#',
                #delimiter=None,
                skip_header=5,
                skip_footer=7,
                #converters= ,
                #missing_values=None,
                #filling_values=None,
                #usecols=None,
                #names=None,
                #excludelist=None,
                #deletechars=None,
                #replace_space='_',
                #autostrip=False,
                #case_sensitive=True,
                #defaultfmt='f%i',
                #unpack=None,
                #usemask=False,
                #loose=True,
                #invalid_raise=True,
                #max_rows=None
               )
f.close()

# %%
a
# Out:
# array([(101, b'Abel', 2, 108, 22, 0, 0.0, 11, 138, 11),
#        (102, b'Adams', 2, 97, 20, 0, 0.0, 11, 138, 12),
#        (103, b'Adler', 1, 180, 37, 0, 0.0, 11, 138, 11),
#        (104, b'Agricola', 1, 74, 15, 0, 0.0, 11, 138, 11),
#        (105, b'Aiken', 1, 71, 14, 0, 0.0, 11, 138, 11),
#        (106, b'Alber', 1, 136, 28, 0, 1.0, 11, 138, 12),
#        (107, b'Alder', 2, 125, 25, 0, 0.0, 11, 138, 12),
#        (108, b'Alger', 1, 171, 35, 0, 0.0, 11, 138, 12),
#        (109, b'Ali', 1, 175, 36, 0, 0.0, 11, 138, 13),
#        (110, b'Allen', 1, 195, 40, 0, 0.0, 11, 138, 13),
#        (111, b'Anna', 1, 0, 0, 0, 0.0, 11, 230, 13),
#        (112, b'Archer', 1, 0, 0, 0, 0.0, 11, 230, 13),
#        (113, b'Arne', 3, 265, 54, 0, 0.0, 12, 230, 14),
#        (114, b'Arnold', 2, 194, 39, 0, 0.0, 12, 230, 16),
#        (115, b'Arthur', 2, 317, 64, 0, 0.0, 12, 230, 16),
#        (116, b'Asser', 2, 100, 20, 0, 0.0, 12, 230, 16),
#        (117, b'Aston', 1, 0, 0, 0, 0.0, 12, 230, 17),
# ...

# %%
len(a)
# Out:
# 73

# %%
a['f0']
# Out:
# array([101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113,
#        114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 201, 202,
#        203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215,
#        216, 217, 218, 219, 220, 221, 222, 223, 224, 301, 302, 303, 304,
#        305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317,
#        318, 319, 320, 321, 322, 323, 324, 325])

# %%
for i in a:
    print (i)
# Out:
# (101, b'Abel', 2, 108, 22, 0, 0.0, 11, 138, 11)
# (102, b'Adams', 2, 97, 20, 0, 0.0, 11, 138, 12)
# (103, b'Adler', 1, 180, 37, 0, 0.0, 11, 138, 11)
# (104, b'Agricola', 1, 74, 15, 0, 0.0, 11, 138, 11)
# (105, b'Aiken', 1, 71, 14, 0, 0.0, 11, 138, 11)
# (106, b'Alber', 1, 136, 28, 0, 1.0, 11, 138, 12)
# (107, b'Alder', 2, 125, 25, 0, 0.0, 11, 138, 12)
# (108, b'Alger', 1, 171, 35, 0, 0.0, 11, 138, 12)
# (109, b'Ali', 1, 175, 36, 0, 0.0, 11, 138, 13)
# (110, b'Allen', 1, 195, 40, 0, 0.0, 11, 138, 13)
# (111, b'Anna', 1, 0, 0, 0, 0.0, 11, 230, 13)
# (112, b'Archer', 1, 0, 0, 0, 0.0, 11, 230, 13)
# (113, b'Arne', 3, 265, 54, 0, 0.0, 12, 230, 14)
# (114, b'Arnold', 2, 194, 39, 0, 0.0, 12, 230, 16)
# (115, b'Arthur', 2, 317, 64, 0, 0.0, 12, 230, 16)
# (116, b'Asser', 2, 100, 20, 0, 0.0, 12, 230, 16)
# (117, b'Aston', 1, 0, 0, 0, 0.0, 12, 230, 17)
# (118, b'Astor', 2, 333, 68, 0, 0.0, 12, 230, 17)
# (119, b'Attar', 1, 181, 37, 0, 0.0, 12, 230, 15)
# ...
